# %% [markdown]
# Importing libraries

# %%
import numpy as np

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
import warnings

# %%
from warnings import filterwarnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('hranalysis.csv')

# %%
df.head()
# Out:
#    Age Attrition     BusinessTravel  DailyRate              Department  \
# 0   41       Yes      Travel_Rarely       1102                   Sales
# 1   49        No  Travel_Frequently        279  Research & Development
# 2   37       Yes      Travel_Rarely       1373  Research & Development
# 3   33        No  Travel_Frequently       1392  Research & Development
# 4   27        No      Travel_Rarely        591  Research & Development
#
#    DistanceFromHome  Education EducationField  EmployeeCount  EmployeeNumber  \
# 0                 1          2  Life Sciences              1               1
# 1                 8          1  Life Sciences              1               2
# 2                 2          2          Other              1               4
# 3                 3          4  Life Sciences              1               5
# 4                 2          1        Medical              1               7
#
#    ...  RelationshipSatisfaction StandardHours  StockOptionLevel  \
# ...

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %% [markdown]
# There are 1470 rows and 35 columns

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1470 entries, 0 to 1469
# Data columns (total 35 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       1470 non-null   int64
#  1   Attrition                 1470 non-null   object
#  2   BusinessTravel            1470 non-null   object
#  3   DailyRate                 1470 non-null   int64
#  4   Department                1470 non-null   object
#  5   DistanceFromHome          1470 non-null   int64
#  6   Education                 1470 non-null   int64
#  7   EducationField            1470 non-null   object
#  8   EmployeeCount             1470 non-null   int64
#  9   EmployeeNumber            1470 non-null   int64
#  10  EnvironmentSatisfaction   1470 non-null   int64
#  11  Gender                    1470 non-null   object
#  12  HourlyRate                1470 non-null   int64
#  13  JobInvolvement            1470 non-null   int64
# ...

# %% [markdown]
# There are no null values

# %%
df.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# We see that Standard hours and EmployeeCount has same min max and percentile values having no effect over change in attrition

# %% [markdown]
# Removing columns having no effect on output

# %%
df.drop(['EmployeeCount','StandardHours'],axis=1,inplace=True)

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'Over18',
#        'OverTime', 'PercentSalaryHike', 'PerformanceRating',
#        'RelationshipSatisfaction', 'StockOptionLevel', 'TotalWorkingYears',
#        'TrainingTimesLastYear', 'WorkLifeBalance', 'YearsAtCompany',
#        'YearsInCurrentRole', 'YearsSinceLastPromotion',
#        'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# Looking at unique values in each column so that we get the idea of which are having numerical values and which are having categorical values.

# %%
df['Age'].unique()
# Out:
# array([41, 49, 37, 33, 27, 32, 59, 30, 38, 36, 35, 29, 31, 34, 28, 22, 53,
#        24, 21, 42, 44, 46, 39, 43, 50, 26, 48, 55, 45, 56, 23, 51, 40, 54,
#        58, 20, 25, 19, 57, 52, 47, 18, 60], dtype=int64)

# %%
df['BusinessTravel'].unique()
# Out:
# array(['Travel_Rarely', 'Travel_Frequently', 'Non-Travel'], dtype=object)

# %%
df['DailyRate'].unique()
# Out:
# array([1102,  279, 1373, 1392,  591, 1005, 1324, 1358,  216, 1299,  809,
#         153,  670, 1346,  103, 1389,  334, 1123, 1219,  371,  673, 1218,
#         419,  391,  699, 1282, 1125,  691,  477,  705,  924, 1459,  125,
#         895,  813, 1273,  869,  890,  852, 1141,  464, 1240, 1357,  994,
#         721, 1360, 1065,  408, 1211, 1229,  626, 1434, 1488, 1097, 1443,
#         515,  853, 1142,  655, 1115,  427,  653,  989, 1435, 1223,  836,
#        1195, 1339,  664,  318, 1225, 1328, 1082,  548,  132,  746,  776,
#         193,  397,  945, 1214,  111,  573, 1153, 1400,  541,  432,  288,
#         669,  530,  632, 1334,  638, 1093, 1217, 1353,  120,  682,  489,
#         807,  827,  871,  665, 1040, 1420,  240, 1280,  534, 1456,  658,
#         142, 1127, 1031, 1189, 1354, 1467,  922,  394, 1312,  750,  441,
#         684,  249,  841,  147,  528,  594,  470,  957,  542,  802, 1355,
#        1150, 1329,  959, 1033, 1316,  364,  438,  689,  201, 1427,  857,
# ...

# %%
df['Department'].unique()
# Out:
# array(['Sales', 'Research & Development', 'Human Resources'], dtype=object)

# %%
df['DistanceFromHome'].unique()
# Out:
# array([ 1,  8,  2,  3, 24, 23, 27, 16, 15, 26, 19, 21,  5, 11,  9,  7,  6,
#        10,  4, 25, 12, 18, 29, 22, 14, 20, 28, 17, 13], dtype=int64)

# %%
df['Education'].unique()
# Out:
# array([2, 1, 4, 3, 5], dtype=int64)

# %%
df['EducationField'].unique()
# Out:
# array(['Life Sciences', 'Other', 'Medical', 'Marketing',
#        'Technical Degree', 'Human Resources'], dtype=object)

# %%
df['EmployeeNumber'].unique()
# Out:
# array([   1,    2,    4, ..., 2064, 2065, 2068], dtype=int64)

# %%
df['EnvironmentSatisfaction'].unique()
# Out:
# array([2, 3, 4, 1], dtype=int64)

# %%
df['Gender'].unique()
# Out:
# array(['Female', 'Male'], dtype=object)

# %%
df['HourlyRate'].unique()
# Out:
# array([ 94,  61,  92,  56,  40,  79,  81,  67,  44,  84,  49,  31,  93,
#         50,  51,  80,  96,  78,  45,  82,  53,  83,  58,  72,  48,  42,
#         41,  86,  97,  75,  33,  37,  73,  98,  36,  47,  71,  30,  43,
#         99,  59,  95,  57,  76,  87,  66,  55,  32,  52,  70,  62,  64,
#         63,  60, 100,  46,  39,  77,  35,  91,  54,  34,  90,  65,  88,
#         85,  89,  68,  69,  74,  38], dtype=int64)

# %%
df['JobInvolvement'].unique()
# Out:
# array([3, 2, 4, 1], dtype=int64)

# %%
df['JobLevel'].unique()
# Out:
# array([2, 1, 3, 4, 5], dtype=int64)

# %%
df['JobRole'].unique()
# Out:
# array(['Sales Executive', 'Research Scientist', 'Laboratory Technician',
#        'Manufacturing Director', 'Healthcare Representative', 'Manager',
#        'Sales Representative', 'Research Director', 'Human Resources'],
#       dtype=object)

# %%
df['JobSatisfaction'].unique()
# Out:
# array([4, 2, 3, 1], dtype=int64)

# %%
df['MaritalStatus'].unique()
# Out:
# array(['Single', 'Married', 'Divorced'], dtype=object)

# %%
df['MonthlyIncome'].unique()
# Out:
# array([5993, 5130, 2090, ..., 9991, 5390, 4404], dtype=int64)

# %%
df['MonthlyRate'].unique()
# Out:
# array([19479, 24907,  2396, ...,  5174, 13243, 10228], dtype=int64)

# %%
df['NumCompaniesWorked'].unique()
# Out:
# array([8, 1, 6, 9, 0, 4, 5, 2, 7, 3], dtype=int64)

# %%
df['Over18'].unique()
# Out:
# array(['Y'], dtype=object)

# %%
df['OverTime'].unique()
# Out:
# array(['Yes', 'No'], dtype=object)

# %%
df['PercentSalaryHike'].unique()
# Out:
# array([11, 23, 15, 12, 13, 20, 22, 21, 17, 14, 16, 18, 19, 24, 25],
#       dtype=int64)

# %%
df['PerformanceRating'].unique()
# Out:
# array([3, 4], dtype=int64)

# %%
df['RelationshipSatisfaction'].unique()
# Out:
# array([1, 4, 2, 3], dtype=int64)

# %%
df['StockOptionLevel'].unique()
# Out:
# array([0, 1, 3, 2], dtype=int64)

# %%
df['TotalWorkingYears'].unique()
# Out:
# array([ 8, 10,  7,  6, 12,  1, 17,  5,  3, 31, 13,  0, 26, 24, 22,  9, 19,
#         2, 23, 14, 15,  4, 29, 28, 21, 25, 20, 11, 16, 37, 38, 30, 40, 18,
#        36, 34, 32, 33, 35, 27], dtype=int64)

# %%
df['TrainingTimesLastYear'].unique()
# Out:
# array([0, 3, 2, 5, 1, 4, 6], dtype=int64)

# %%
df['WorkLifeBalance'].unique()
# Out:
# array([1, 3, 2, 4], dtype=int64)

# %%
df['YearsAtCompany'].unique()
# Out:
# array([ 6, 10,  0,  8,  2,  7,  1,  9,  5,  4, 25,  3, 12, 14, 22, 15, 27,
#        21, 17, 11, 13, 37, 16, 20, 40, 24, 33, 19, 36, 18, 29, 31, 32, 34,
#        26, 30, 23], dtype=int64)

# %%
df['YearsInCurrentRole'].unique()
# Out:
# array([ 4,  7,  0,  2,  5,  9,  8,  3,  6, 13,  1, 15, 14, 16, 11, 10, 12,
#        18, 17], dtype=int64)

# %%
df['YearsSinceLastPromotion'].unique()
# Out:
# array([ 0,  1,  3,  2,  7,  4,  8,  6,  5, 15,  9, 13, 12, 10, 11, 14],
#       dtype=int64)

# %%
df['YearsWithCurrManager'].unique()
# Out:
# array([ 5,  7,  0,  2,  6,  8,  3, 11, 17,  1,  4, 12,  9, 10, 15, 13, 16,
#        14], dtype=int64)

# %% [markdown]
# From the above observation, we findout that Over18 is having only 1 unique value. Such data adds no meaning to the output and thus we drop the column

# %%
df.drop(['Over18'],axis=1,inplace=True)

# %%
df
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
df.dtypes
# Out:
# Age                          int64
# Attrition                   object
# BusinessTravel              object
# DailyRate                    int64
# Department                  object
# DistanceFromHome             int64
# Education                    int64
# EducationField              object
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                      object
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                     object
# JobSatisfaction              int64
# MaritalStatus               object
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                    object
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# ...

# %%
sns.countplot(df['Attrition'])

# %% [markdown]
# We see that in the target, there is a data imbalance present. Same can be removed by SMOTE

# %% [markdown]
# Converting categorical variables to numerical

# %%
df.isnull().sum()
# Out:
# Age                         0
# Attrition                   0
# BusinessTravel              0
# DailyRate                   0
# Department                  0
# DistanceFromHome            0
# Education                   0
# EducationField              0
# EmployeeNumber              0
# EnvironmentSatisfaction     0
# Gender                      0
# HourlyRate                  0
# JobInvolvement              0
# JobLevel                    0
# JobRole                     0
# JobSatisfaction             0
# MaritalStatus               0
# MonthlyIncome               0
# MonthlyRate                 0
# NumCompaniesWorked          0
# OverTime                    0
# PercentSalaryHike           0
# PerformanceRating           0
# RelationshipSatisfaction    0
# StockOptionLevel            0
# TotalWorkingYears           0
# TrainingTimesLastYear       0
# WorkLifeBalance             0
# YearsAtCompany              0
# YearsInCurrentRole          0
# YearsSinceLastPromotion     0
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
LE=LabelEncoder()

# %%
df['Attrition']=LE.fit_transform(df['Attrition'])

# %%
df
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
df['BusinessTravel']=LE.fit_transform(df['BusinessTravel'])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate              Department  \
# 0      41          1               2       1102                   Sales
# 1      49          0               1        279  Research & Development
# 2      37          1               2       1373  Research & Development
# 3      33          0               1       1392  Research & Development
# 4      27          0               2        591  Research & Development
# ...   ...        ...             ...        ...                     ...
# 1465   36          0               1        884  Research & Development
# 1466   39          0               2        613  Research & Development
# 1467   27          0               2        155  Research & Development
# 1468   49          0               1       1023                   Sales
# 1469   34          0               2        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeNumber  \
# ...

# %%
df['Department']=LE.fit_transform(df['Department'])

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df['EducationField']=LE.fit_transform(df['EducationField'])
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df['Gender']=LE.fit_transform(df['Gender'])
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
df.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'DailyRate', 'Department',
#        'DistanceFromHome', 'Education', 'EducationField', 'EmployeeNumber',
#        'EnvironmentSatisfaction', 'Gender', 'HourlyRate', 'JobInvolvement',
#        'JobLevel', 'JobRole', 'JobSatisfaction', 'MaritalStatus',
#        'MonthlyIncome', 'MonthlyRate', 'NumCompaniesWorked', 'OverTime',
#        'PercentSalaryHike', 'PerformanceRating', 'RelationshipSatisfaction',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'WorkLifeBalance', 'YearsAtCompany', 'YearsInCurrentRole',
#        'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
df['JobRole']=LE.fit_transform(df['JobRole'])

# %%
df['MaritalStatus']=LE.fit_transform(df['MaritalStatus'])

# %%
df['OverTime']=LE.fit_transform(df['OverTime'])

# %%
df.dtypes
# Out:
# Age                         int64
# Attrition                   int32
# BusinessTravel              int32
# DailyRate                   int64
# Department                  int32
# DistanceFromHome            int64
# Education                   int64
# EducationField              int32
# EmployeeNumber              int64
# EnvironmentSatisfaction     int64
# Gender                      int32
# HourlyRate                  int64
# JobInvolvement              int64
# JobLevel                    int64
# JobRole                     int32
# JobSatisfaction             int64
# MaritalStatus               int32
# MonthlyIncome               int64
# MonthlyRate                 int64
# NumCompaniesWorked          int64
# OverTime                    int32
# PercentSalaryHike           int64
# PerformanceRating           int64
# RelationshipSatisfaction    int64
# StockOptionLevel            int64
# TotalWorkingYears           int64
# TrainingTimesLastYear       int64
# ...

# %%
df
# Out:
#       Age  Attrition  BusinessTravel  DailyRate  Department  DistanceFromHome  \
# 0      41          1               2       1102           2                 1
# 1      49          0               1        279           1                 8
# 2      37          1               2       1373           1                 2
# 3      33          0               1       1392           1                 3
# 4      27          0               2        591           1                 2
# ...   ...        ...             ...        ...         ...               ...
# 1465   36          0               1        884           1                23
# 1466   39          0               2        613           1                 6
# 1467   27          0               2        155           1                 4
# 1468   49          0               1       1023           2                 2
# 1469   34          0               2        628           1                 8
#
# ...

# %%
x=df.drop(['Attrition'],axis=1)

# %%
x.shape
# Out:
# (1470, 31)

# %%
y=df['Attrition']

# %%
y.shape
# Out:
# (1470,)

# %%
from imblearn.over_sampling import SMOTE

# %%
smt=SMOTE()

# %%
trainx,trainy=smt.fit_resample(x,y)

# %%
trainy.value_counts()
# Out:
# 1    1233
# 0    1233
# Name: Attrition, dtype: int64

# %% [markdown]
# Class imblanace issue is resolved

# %%
from sklearn.preprocessing import StandardScaler

# %%
ss=StandardScaler()

# %%
trainx=ss.fit_transform(trainx)

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.svm import SVC

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
from sklearn.naive_bayes import GaussianNB

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
from sklearn.metrics import classification_report

# %%
from sklearn.metrics import accuracy_score

# %%
maxAccu=0
maxRS=0

# %%
for i in range(1,200):
    x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=.30,random_state=i)
    model=DecisionTreeClassifier()
    model.fit(x_train,y_train)
    predm=model.predict(x_test)
    acc=accuracy_score(y_test,predm)
    if acc>maxAccu:
        maxAccu=acc
        maxRS=i
print('Best Accuracy is',maxAccu,'on Random State',maxRS)
# Out:
# Best Accuracy is 0.8554054054054054 on Random State 94

# %%
x_train,x_test,y_train,y_test=train_test_split(trainx,trainy,test_size=.30,random_state=94)

# %%
DTC=DecisionTreeClassifier()

# %%
DTC.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
pred_dtc=DTC.predict(x_test)

# %%
acc_dtc=classification_report(y_test,pred_dtc)

# %%
print(acc_dtc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.86      0.85       369
#            1       0.85      0.83      0.84       371
#
#     accuracy                           0.84       740
#    macro avg       0.84      0.84      0.84       740
# weighted avg       0.84      0.84      0.84       740

# %%
RFC=RandomForestClassifier()

# %%
RFC.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
pred_rfc=RFC.predict(x_test)

# %%
acc_rfc=classification_report(y_test,pred_rfc)

# %%
print(acc_rfc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.94      0.92       369
#            1       0.94      0.91      0.92       371
#
#     accuracy                           0.92       740
#    macro avg       0.92      0.92      0.92       740
# weighted avg       0.92      0.92      0.92       740

# %%
SV=SVC()
SV.fit(x_train,y_train)
pred_svc=SV.predict(x_test)
acc_svc=classification_report(y_test,pred_svc)
print(acc_svc)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.90      0.91       369
#            1       0.90      0.91      0.91       371
#
#     accuracy                           0.91       740
#    macro avg       0.91      0.91      0.91       740
# weighted avg       0.91      0.91      0.91       740

# %%
gnb=GaussianNB()
gnb.fit(x_train,y_train)
pred_gnb=gnb.predict(x_test)
acc_gnb=classification_report(y_test,pred_gnb)
print(acc_gnb)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.67      0.72       369
#            1       0.71      0.80      0.75       371
#
#     accuracy                           0.74       740
#    macro avg       0.74      0.74      0.74       740
# weighted avg       0.74      0.74      0.74       740

# %%
from sklearn.model_selection import cross_val_score

# %%
print(cross_val_score(DTC,trainx,trainy,cv=5).mean())
# Out:
# 0.6934672458959851

# %%
print(cross_val_score(RFC,trainx,trainy,cv=5).mean())
# Out:
# 0.815526685335589

# %%
print(cross_val_score(SV,trainx,trainy,cv=5).mean())
# Out:
# 0.8577575941726684

# %%
print(cross_val_score(gnb,x,y,cv=5).mean())
# Out:
# 0.7972789115646259

# %% [markdown]
# SVC is the best model based on classification report and cross validation score

# %%
from sklearn.model_selection import GridSearchCV

# %%
parameter={'shrinking':[True,False],'probability':[True,False],'verbose':[True,False],'break_ties':[True,False]}

# %%
GCV=GridSearchCV(SVC(),parameter,cv=5)

# %%
GCV.fit(x_train,y_train)
# Out:
# [LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM][LibSVM]
# GridSearchCV(cv=5, estimator=SVC(),
#              param_grid={'break_ties': [True, False],
#                          'probability': [True, False],
#                          'shrinking': [True, False], 'verbose': [True, False]})

# %%
GCV.best_params_
# Out:
# {'break_ties': True, 'probability': True, 'shrinking': True, 'verbose': True}

# %%
Finalmod=SVC(shrinking=True,probability=True,verbose=True,break_ties=True)

# %%
Finalmod.fit(x_train,y_train)
pred_fin=Finalmod.predict(x_test)
acc_fin=accuracy_score(y_test,pred_fin)
print(acc_fin*100)
# Out:
# [LibSVM]90.81081081081082

# %%
from sklearn.metrics import roc_curve

# %%
from sklearn.metrics import roc_auc_score

# %%
SC=SVC(probability=True)

# %%
SC.fit(x_train,y_train)
# Out:
# SVC(probability=True)

# %%
y_pred_prob=SC.predict_proba(x_test)[:,1]

# %%
y_pred_prob
# Out:
# array([1.45387084e-01, 1.32093538e-01, 1.18738219e-01, 1.25298463e-02,
#        2.84269892e-01, 2.13879973e-02, 8.29711945e-01, 9.85524267e-01,
#        9.24720791e-01, 2.40052264e-02, 9.80276677e-01, 6.22272338e-01,
#        9.38416740e-01, 9.17073292e-01, 9.51395382e-01, 9.01580316e-02,
#        8.62475094e-01, 9.61362775e-01, 3.09258399e-01, 9.19407553e-01,
#        4.12290481e-03, 2.49406448e-01, 5.10825081e-02, 1.34551561e-01,
#        5.65675330e-01, 6.76803438e-01, 5.43557803e-01, 4.78956632e-02,
#        4.76544665e-02, 9.97013644e-01, 9.94532383e-01, 3.97337174e-02,
#        1.42948629e-01, 7.72117002e-02, 6.29885512e-01, 1.81930447e-01,
#        9.40632855e-01, 4.78776825e-02, 7.58605376e-02, 8.65449254e-01,
#        4.02275294e-01, 3.45617077e-02, 6.22163421e-01, 6.48673574e-01,
#        9.90502852e-01, 5.92391217e-02, 9.97263095e-01, 9.89534784e-01,
#        7.69859450e-02, 2.11170887e-01, 6.73274738e-01, 9.83764058e-01,
# ...

# %%
y_pred_prob.shape
# Out:
# (740,)

# %%
fpr,tpr,thresholds=roc_curve(y_test,y_pred_prob)

# %%
plt.plot([0,1],[0,1],'k--')

# %%
plt.plot(fpr,tpr,label='SV Classifier')
plt.xlabel('False Positive rate')
plt.ylabel('True Positive rate')
plt.title('SVC')
plt.show()

# %%
auc_score=roc_auc_score(y_test,SV.predict(x_test))

# %%
auc_score
# Out:
# 0.9080928275590034

# %%
import joblib

# %%
joblib.dump(Finalmod,'UploadHRanalysis.pkl')
# Out:
# ['UploadHRanalysis.pkl']
